# %%
import pandas as pd
import numpy as np

# %%
# Read in and show the the med_full_final_melted.csv file
med_claims = pd.read_csv('Data/med_full_final_melted.csv')
med_claims = med_claims.drop('Unnamed: 0', axis = 1)
med_claims
# Out:
#           Member Life ID Biological Gender  Subscriber Zip Code  \
# 0                 109514                 F              20678.0
# 1                 109514                 F              20678.0
# 2                 109514                 F              20678.0
# 3                 109514                 F              20678.0
# 4                 109514                 F              20678.0
# ...                  ...               ...                  ...
# 15711868        25236738                 F              21401.0
# 15711869        25236738                 F              21401.0
# 15711870        25236738                 F              21401.0
# 15711871         2797724                 F              22301.0
# 15711872         2797724                 F              22301.0
#
#          Current Procedural Terminology CPT Modifier 1 CPT Modifier 2  \
# 0                                 A7035             NU            NaN
# 1                                 99213            NaN            NaN
# 2                                 A7034             NU            NaN
# 3                                 A7032             NU            NaN
# 4                                 A7035             NU            NaN
# ...                                 ...            ...            ...
# 15711868                          84439            NaN            NaN
# 15711869                          84443            NaN            NaN
# 15711870                          36415            NaN            NaN
# 15711871                          82728            NaN            NaN
# 15711872                          83789            NaN            NaN
#
#          Line Service From Date Line Service Thru Date  \
# 0                    2017-08-10             2017-08-10
# 1                    2017-10-17             2017-10-17
# 2                    2017-11-15             2017-11-15
# 3                    2017-11-15             2017-11-15
# 4                    2017-11-15             2017-11-15
# ...                         ...                    ...
# 15711868             2017-11-20             2017-11-20
# 15711869             2018-11-26             2018-11-26
# 15711870             2018-11-26             2018-11-26
# 15711871             2017-12-02             2017-12-02
# 15711872             2017-12-02             2017-12-02
#
#          Header Service From Date Header Service Thru Date  Billed Amount  \
# 0                      2017-08-10               2017-08-10          40.00
# 1                      2017-10-17               2017-10-17         121.00
# 2                      2017-11-15               2017-11-15         125.00
# 3                      2017-11-15               2017-11-15          90.00
# 4                      2017-11-15               2017-11-15          40.00
# ...                           ...                      ...            ...
# 15711868               2017-11-20               2017-11-20          24.74
# 15711869               2018-11-26               2018-11-26          41.50
# 15711870               2018-11-26               2018-11-26           6.00
# 15711871               2017-12-02               2017-12-02          85.48
# 15711872               2017-12-02               2017-12-02          80.48
#
#                          Diagnosis Type Diagnosis Base Code
# 0          Primary Diagnosis Code-ICD10     G4733       G47
# 1          Primary Diagnosis Code-ICD10     J0191       J01
# 2          Primary Diagnosis Code-ICD10     G4733       G47
# 3          Primary Diagnosis Code-ICD10     G4733       G47
# 4          Primary Diagnosis Code-ICD10     G4733       G47
# ...                                 ...       ...       ...
# 15711868  Tertiary Diagnosis Code-ICD10      E782       E78
# 15711869  Tertiary Diagnosis Code-ICD10      E039       E03
# 15711870  Tertiary Diagnosis Code-ICD10      E039       E03
# 15711871  Tertiary Diagnosis Code-ICD10      E063       E06
# 15711872  Tertiary Diagnosis Code-ICD10      E063       E06
#
# [15711873 rows x 14 columns]

# %%
# Create a list of the unique Member Life IDs
unique_ids = np.unique(med_claims['Member Life ID'])

edges_dict = {}

for current_id in unique_ids:
    # Slice the medical claims dataframe to get only the rows where Member Life ID equals the current_id
    current_slice = med_claims.loc[med_claims['Member Life ID'] == current_id]

    current_base_codes = np.sort(np.unique(current_slice['Base Code']))

    # Create a list of edges to include in the edges_dict dictionary.
    current_edges = []
    for node_1 in current_base_codes:
        for node_2 in current_base_codes:
            if node_1 != node_2 and (node_2, node_1) not in current_edges:
                current_edges.append((node_1, node_2))

    # Loop through the current_edges list and update the edges_dict dictionary appropriately.
    for edge in current_edges:
        node_1 = edge[0]
        node_2 = edge[1]

        if edge in edges_dict.keys():
            edges_dict[edge] = edges_dict[edge] + 1
        else:
            edges_dict[edge] = 1

# %%
edges_dict
# Out:
# {('B35', 'D22'): 670,
#  ('B35', 'D48'): 696,
#  ('B35', 'D53'): 40,
#  ('B35', 'D61'): 33,
#  ('B35', 'D64'): 566,
#  ('B35', 'D69'): 162,
#  ('B35', 'E04'): 236,
#  ('B35', 'E86'): 270,
#  ('B35', 'E87'): 469,
#  ('B35', 'E88'): 67,
#  ('B35', 'H11'): 124,
#  ('B35', 'H25'): 928,
#  ('B35', 'H35'): 555,
#  ('B35', 'H52'): 463,
#  ('B35', 'H61'): 449,
#  ('B35', 'H90'): 380,
#  ('B35', 'I10'): 2590,
#  ('B35', 'I11'): 352,
#  ('B35', 'I12'): 280,
#  ('B35', 'I13'): 123,
#  ('B35', 'I20'): 108,
#  ('B35', 'I21'): 108,
#  ('B35', 'I25'): 794,
#  ('B35', 'I42'): 148,
#  ('B35', 'I44'): 166,
#  ('B35', 'I48'): 460,
#  ('B35', 'I50'): 397,
#  ('B35', 'I51'): 388,
#  ('B35', 'I95'): 235,
#  ('B35', 'J18'): 384,
#  ('B35', 'J81'): 107,
#  ('B35', 'J90'): 230,
#  ('B35', 'J96'): 192,
#  ('B35', 'J98'): 404,
#  ('B35', 'K21'): 985,
#  ('B35', 'K57'): 468,
#  ('B35', 'L21'): 247,
#  ('B35', 'L30'): 634,
#  ('B35', 'L53'): 114,
#  ('B35', 'L57'): 763,
#  ('B35', 'L82'): 887,
#  ('B35', 'N17'): 293,
#  ('B35', 'N18'): 493,
#  ('B35', 'N28'): 376,
#  ('B35', 'N40'): 462,
#  ('B35', 'R00'): 600,
#  ('B35', 'R05'): 1149,
#  ('B35', 'R06'): 1169,
#  ('B35', 'R07'): 1150,
#  ('B35', 'R09'): 657,
#  ('B35', 'R11'): 502,
#  ('B35', 'R13'): 281,
#  ('B35', 'R49'): 74,
#  ('B35', 'R60'): 725,
#  ('B35', 'R63'): 362,
#  ('B35', 'R68'): 375,
#  ('B35', 'R74'): 201,
#  ('B35', 'R79'): 332,
#  ('B35', 'R93'): 277,
#  ('B35', 'Z12'): 1546,
#  ('B35', 'Z23'): 2325,
#  ('B35', 'Z68'): 806,
#  ('B35', 'Z71'): 440,
#  ('B35', 'Z74'): 608,
#  ('B35', 'Z85'): 517,
#  ('B35', 'Z95'): 301,
#  ('D22', 'D48'): 3489,
#  ('D22', 'D53'): 22,
#  ('D22', 'D61'): 24,
#  ('D22', 'D64'): 435,
#  ('D22', 'D69'): 155,
#  ('D22', 'E04'): 368,
#  ('D22', 'E86'): 161,
#  ('D22', 'E87'): 263,
#  ('D22', 'E88'): 65,
#  ('D22', 'H11'): 185,
#  ('D48', 'L53'): 394,
#  ('D48', 'L57'): 2848,
#  ('D48', 'L82'): 3283,
#  ('D48', 'N17'): 132,
#  ('D48', 'N18'): 299,
#  ('D48', 'N28'): 365,
#  ('D48', 'N40'): 611,
#  ('D48', 'R00'): 738,
#  ('D48', 'R05'): 1359,
#  ('D48', 'R06'): 1121,
#  ('D48', 'R07'): 1219,
#  ('D48', 'R09'): 611,
#  ('D48', 'R11'): 505,
#  ('D48', 'R13'): 293,
#  ('D48', 'R49'): 101,
#  ('D48', 'R60'): 496,
#  ('D48', 'R63'): 331,
#  ('D48', 'R68'): 398,
#  ('D48', 'R74'): 185,
#  ('D48', 'R79'): 353,
#  ('D48', 'R93'): 363,
#  ('D48', 'Z12'): 2883,
#  ('D48', 'Z23'): 3381,
#  ('D48', 'Z68'): 1023,
#  ('D48', 'Z71'): 559,
#  ('D48', 'Z74'): 329,
#  ('D48', 'Z85'): 1408,
#  ('D48', 'Z95'): 267,
#  ('D53', 'D61'): 22,
#  ('D53', 'D64'): 132,
#  ('D53', 'D69'): 28,
#  ('D53', 'E04'): 11,
#  ('D53', 'E86'): 34,
#  ('D53', 'E87'): 58,
#  ('D53', 'E88'): 11,
#  ('D53', 'H11'): 8,
#  ('D53', 'H25'): 54,
#  ('D53', 'H35'): 29,
#  ('D53', 'H52'): 31,
#  ('D53', 'H61'): 21,
#  ('D53', 'H90'): 17,
#  ('D53', 'I10'): 172,
#  ('D53', 'I11'): 32,
#  ('D53', 'I12'): 20,
#  ('D53', 'I13'): 13,
#  ('D53', 'I20'): 10,
#  ('D53', 'I21'): 13,
#  ('D53', 'I25'): 59,
#  ('D53', 'I42'): 13,
#  ('D53', 'I44'): 9,
#  ('D53', 'I48'): 39,
#  ('D53', 'I50'): 41,
#  ('D53', 'I51'): 44,
#  ('D53', 'I95'): 33,
#  ('D53', 'J18'): 36,
#  ('D53', 'J81'): 12,
#  ('D53', 'J90'): 38,
#  ('D53', 'J96'): 21,
#  ('D53', 'J98'): 48,
#  ('D53', 'K21'): 87,
#  ('D53', 'K57'): 31,
#  ('D53', 'L21'): 9,
#  ('D53', 'L30'): 24,
#  ('D53', 'L53'): 7,
#  ('D53', 'L57'): 34,
#  ('D53', 'L82'): 42,
#  ('D53', 'N17'): 47,
#  ('D53', 'N18'): 51,
#  ('D53', 'N28'): 46,
#  ('D53', 'N40'): 31,
#  ('D53', 'R00'): 53,
#  ('D53', 'R05'): 79,
#  ('D53', 'R06'): 102,
#  ('D53', 'R07'): 88,
#  ('D53', 'R09'): 48,
#  ('D53', 'R11'): 50,
#  ('D53', 'R13'): 32,
#  ('D53', 'R49'): 7,
#  ('D53', 'R60'): 72,
#  ('D53', 'R63'): 43,
#  ('D53', 'R68'): 21,
#  ('D53', 'R74'): 26,
#  ('D53', 'R79'): 55,
#  ('D53', 'R93'): 38,
#  ('D53', 'Z12'): 92,
#  ('D53', 'Z23'): 132,
#  ('D53', 'Z68'): 55,
#  ('D53', 'Z71'): 30,
#  ('D53', 'Z74'): 62,
#  ('D53', 'Z85'): 50,
#  ('D53', 'Z95'): 23,
#  ('D61', 'D64'): 139,
#  ('D61', 'D69'): 103,
#  ('D61', 'E04'): 14,
#  ('D61', 'E86'): 60,
#  ('D61', 'E87'): 78,
#  ('D61', 'E88'): 19,
#  ('D61', 'H11'): 8,
#  ('D61', 'H25'): 37,
#  ('D61', 'H35'): 25,
#  ('D61', 'H52'): 17,
#  ('D61', 'H61'): 17,
#  ('D61', 'H90'): 14,
#  ('D61', 'I10'): 140,
#  ('D61', 'I11'): 25,
#  ('D61', 'I12'): 37,
#  ('D61', 'I13'): 20,
#  ('D61', 'I20'): 11,
#  ('D61', 'I21'): 10,
#  ('D61', 'I25'): 58,
#  ('D61', 'I42'): 16,
#  ('D61', 'I44'): 16,
#  ('D61', 'I48'): 39,
#  ('D61', 'I50'): 38,
#  ('D61', 'I51'): 51,
#  ('D61', 'I95'): 39,
#  ('D61', 'J18'): 64,
#  ('D61', 'J81'): 28,
#  ('D61', 'J90'): 53,
#  ('D61', 'J96'): 33,
#  ('D61', 'J98'): 64,
#  ('D61', 'K21'): 60,
#  ('D61', 'K57'): 31,
#  ('D61', 'L21'): 7,
#  ('D61', 'L30'): 18,
#  ('D61', 'L53'): 12,
#  ('D61', 'L57'): 36,
#  ('D61', 'L82'): 39,
#  ('D61', 'N17'): 66,
#  ('D61', 'N18'): 67,
#  ('D61', 'N28'): 45,
#  ('D61', 'N40'): 32,
#  ('D61', 'R00'): 70,
#  ('D61', 'R05'): 73,
#  ('D61', 'R06'): 118,
#  ('D61', 'R07'): 88,
#  ('D61', 'R09'): 63,
#  ('D61', 'R11'): 72,
#  ('D61', 'R13'): 33,
#  ('D61', 'R49'): 4,
#  ('D61', 'R60'): 61,
#  ('D61', 'R63'): 40,
#  ('D61', 'R68'): 26,
#  ('D61', 'R74'): 27,
#  ('D61', 'R79'): 50,
#  ('D61', 'R93'): 48,
#  ('D61', 'Z12'): 66,
#  ('D61', 'Z23'): 95,
#  ('D61', 'Z68'): 36,
#  ('D61', 'Z71'): 30,
#  ('D61', 'Z74'): 68,
#  ('D61', 'Z85'): 75,
#  ('D61', 'Z95'): 26,
#  ('D64', 'D69'): 345,
#  ('D64', 'E04'): 300,
#  ('D64', 'E86'): 460,
#  ('D64', 'E87'): 876,
#  ('D64', 'E88'): 117,
#  ('D64', 'H11'): 116,
#  ('D64', 'H25'): 724,
#  ('D64', 'H35'): 459,
#  ('D64', 'H52'): 428,
#  ('D64', 'H61'): 324,
#  ('D64', 'H90'): 274,
#  ('D64', 'I10'): 2712,
#  ('D64', 'I11'): 453,
#  ('D64', 'I12'): 396,
#  ('D64', 'I13'): 199,
#  ('D64', 'I20'): 165,
#  ('D64', 'I21'): 162,
#  ('D64', 'I25'): 902,
#  ('D64', 'I42'): 267,
#  ('D64', 'I44'): 195,
#  ('D64', 'I48'): 527,
#  ('D64', 'I50'): 542,
#  ('D64', 'I51'): 581,
#  ('D64', 'I95'): 457,
#  ('D64', 'J18'): 530,
#  ('D64', 'J81'): 223,
#  ('D64', 'J90'): 511,
#  ('D64', 'J96'): 360,
#  ('D64', 'J98'): 689,
#  ('D69', 'Z95'): 128,
#  ('E04', 'E86'): 105,
#  ('E04', 'E87'): 163,
#  ('E04', 'E88'): 46,
#  ('E04', 'H11'): 83,
#  ('E04', 'H25'): 436,
#  ('E04', 'H35'): 245,
#  ('E04', 'H52'): 267,
#  ('E04', 'H61'): 178,
#  ('E04', 'H90'): 184,
#  ('E04', 'I10'): 1200,
#  ('E04', 'I11'): 110,
#  ('E04', 'I12'): 80,
#  ('E04', 'I13'): 19,
#  ('E04', 'I20'): 46,
#  ('E04', 'I21'): 25,
#  ('E04', 'I25'): 227,
#  ('E04', 'I42'): 49,
#  ('E04', 'I44'): 47,
#  ('E04', 'I48'): 121,
#  ('E04', 'I50'): 92,
#  ('E04', 'I51'): 133,
#  ('E04', 'I95'): 78,
#  ('E04', 'J18'): 118,
#  ('E04', 'J81'): 18,
#  ('E04', 'J90'): 64,
#  ('E04', 'J96'): 38,
#  ('E04', 'J98'): 178,
#  ('E04', 'K21'): 620,
#  ('E04', 'K57'): 219,
#  ('E04', 'L21'): 78,
#  ('E04', 'L30'): 191,
#  ('E04', 'L53'): 58,
#  ('E04', 'L57'): 304,
#  ('E04', 'L82'): 449,
#  ('E04', 'N17'): 75,
#  ('E04', 'N18'): 133,
#  ('E04', 'N28'): 182,
#  ('E04', 'N40'): 94,
#  ('E04', 'R00'): 406,
#  ('E04', 'R05'): 586,
#  ('E04', 'R06'): 554,
#  ('E04', 'R07'): 639,
#  ('E04', 'R09'): 293,
#  ('E04', 'R11'): 299,
#  ('E04', 'R13'): 194,
#  ('E04', 'R49'): 75,
#  ('E04', 'R60'): 242,
#  ('E04', 'R63'): 234,
#  ('E04', 'R68'): 208,
#  ('E04', 'R74'): 112,
#  ('E04', 'R79'): 233,
#  ('E04', 'R93'): 211,
#  ('E04', 'Z12'): 1341,
#  ('E04', 'Z23'): 1289,
#  ('E04', 'Z68'): 504,
#  ('E04', 'Z71'): 228,
#  ('E04', 'Z74'): 170,
#  ('E04', 'Z85'): 296,
#  ('E04', 'Z95'): 84,
#  ('E86', 'E87'): 577,
#  ('E86', 'E88'): 51,
#  ('E86', 'H11'): 29,
#  ('E86', 'H25'): 268,
#  ('E86', 'H35'): 163,
#  ('E86', 'H52'): 146,
#  ('E86', 'H61'): 135,
#  ('E86', 'H90'): 117,
#  ('E86', 'I10'): 1043,
#  ('E86', 'I11'): 165,
#  ('E86', 'I12'): 164,
#  ('E86', 'I13'): 63,
#  ('E86', 'I20'): 65,
#  ('E86', 'I21'): 65,
#  ('E86', 'I25'): 384,
#  ('E86', 'I42'): 97,
#  ('E86', 'I44'): 70,
#  ('E86', 'I48'): 245,
#  ('E86', 'I50'): 205,
#  ('E86', 'I51'): 252,
#  ('E86', 'I95'): 316,
#  ('E86', 'J18'): 295,
#  ('E86', 'J81'): 86,
#  ('E86', 'J90'): 218,
#  ('E86', 'J96'): 171,
#  ('E86', 'J98'): 330,
#  ('E86', 'K21'): 499,
#  ('E86', 'K57'): 267,
#  ('E86', 'L21'): 60,
#  ('E86', 'L30'): 143,
#  ('E86', 'L53'): 49,
#  ('E86', 'L57'): 183,
#  ('E86', 'L82'): 215,
#  ('E86', 'N17'): 395,
#  ('E86', 'N18'): 286,
#  ('E86', 'N28'): 281,
#  ('E86', 'N40'): 187,
#  ('E86', 'R00'): 507,
#  ('E86', 'R05'): 673,
#  ('E86', 'R06'): 743,
#  ('E86', 'R07'): 759,
#  ('E86', 'R09'): 391,
#  ('E86', 'R11'): 809,
#  ('E86', 'R13'): 193,
#  ('E86', 'R49'): 43,
#  ('E86', 'R60'): 322,
#  ('E86', 'R63'): 319,
#  ('E86', 'R68'): 247,
#  ('E86', 'R74'): 149,
#  ('E86', 'R79'): 237,
#  ('E86', 'R93'): 237,
#  ('E86', 'Z12'): 525,
#  ('E86', 'Z23'): 957,
#  ('E86', 'Z68'): 345,
#  ('E86', 'Z71'): 221,
#  ('E86', 'Z74'): 487,
#  ('E86', 'Z85'): 280,
#  ('E86', 'Z95'): 177,
#  ('E87', 'E88'): 81,
#  ('E87', 'H11'): 68,
#  ('E87', 'H25'): 605,
#  ('E87', 'H35'): 377,
#  ('E87', 'H52'): 294,
#  ('E87', 'H61'): 216,
#  ('E87', 'H90'): 204,
#  ('E87', 'I10'): 2212,
#  ('E87', 'I11'): 420,
#  ('E87', 'I12'): 428,
#  ('E87', 'I13'): 226,
#  ('E87', 'I20'): 136,
#  ('E87', 'I21'): 207,
#  ('E87', 'I25'): 782,
#  ('E87', 'I42'): 246,
#  ('E87', 'I44'): 171,
#  ('E87', 'I48'): 518,
#  ('E87', 'I50'): 589,
#  ('E87', 'I51'): 611,
#  ('E87', 'I95'): 490,
#  ('E87', 'J18'): 560,
#  ('E87', 'J81'): 262,
#  ('E87', 'J90'): 503,
#  ('E87', 'J96'): 456,
#  ('E87', 'J98'): 674,
#  ('E87', 'K21'): 769,
#  ('E87', 'K57'): 427,
#  ('E87', 'L21'): 95,
#  ('E87', 'L30'): 193,
#  ('E87', 'L53'): 57,
#  ('E87', 'L57'): 353,
#  ('E87', 'L82'): 396,
#  ('E87', 'N17'): 694,
#  ('E87', 'N18'): 725,
#  ('E87', 'N28'): 510,
#  ('E87', 'N40'): 317,
#  ('E87', 'R00'): 844,
#  ('E87', 'R05'): 930,
#  ('E87', 'R06'): 1344,
#  ('E87', 'R07'): 1244,
#  ('E87', 'R09'): 750,
#  ('E87', 'R11'): 763,
#  ('E87', 'R13'): 304,
#  ('E87', 'R49'): 63,
#  ('E87', 'R60'): 752,
#  ('E87', 'R63'): 431,
#  ('E87', 'R68'): 410,
#  ('E87', 'R74'): 328,
#  ('E87', 'R79'): 531,
#  ('E87', 'R93'): 416,
#  ('E87', 'Z12'): 1002,
#  ('E87', 'Z23'): 1378,
#  ('E87', 'Z68'): 551,
#  ('E87', 'Z71'): 314,
#  ('E87', 'Z74'): 878,
#  ('E87', 'Z85'): 456,
#  ('E87', 'Z95'): 361,
#  ('E88', 'H11'): 14,
#  ('E88', 'H25'): 97,
#  ('E88', 'H35'): 46,
#  ('E88', 'H52'): 58,
#  ('E88', 'H61'): 48,
#  ('E88', 'H90'): 41,
#  ('E88', 'I10'): 356,
#  ('E88', 'I11'): 53,
#  ('E88', 'I12'): 32,
#  ('E88', 'I13'): 12,
#  ('E88', 'I20'): 18,
#  ('E88', 'I21'): 19,
#  ('E88', 'I25'): 93,
#  ('E88', 'I42'): 27,
#  ('E88', 'I44'): 14,
#  ('E88', 'I48'): 49,
#  ('E88', 'I50'): 47,
#  ('E88', 'I51'): 54,
#  ('E88', 'I95'): 36,
#  ('E88', 'J18'): 52,
#  ('E88', 'J81'): 26,
#  ('E88', 'J90'): 44,
#  ('E88', 'J96'): 28,
#  ('E88', 'J98'): 61,
#  ('E88', 'K21'): 154,
#  ('E88', 'K57'): 65,
#  ('E88', 'L21'): 14,
#  ('E88', 'L30'): 52,
#  ('E88', 'L53'): 17,
#  ('E88', 'L57'): 68,
#  ('E88', 'L82'): 79,
#  ('E88', 'N17'): 53,
#  ('E88', 'N18'): 55,
#  ('E88', 'N28'): 56,
#  ('E88', 'N40'): 53,
#  ('E88', 'R00'): 93,
#  ('E88', 'R05'): 142,
#  ('E88', 'R06'): 184,
#  ('E88', 'R07'): 182,
#  ('E88', 'R09'): 95,
#  ('E88', 'R11'): 100,
#  ('E88', 'R13'): 38,
#  ('E88', 'R49'): 5,
#  ('E88', 'R60'): 96,
#  ('E88', 'R63'): 83,
#  ('E88', 'R68'): 63,
#  ('E88', 'R74'): 53,
#  ('E88', 'R79'): 84,
#  ('E88', 'R93'): 53,
#  ('E88', 'Z12'): 257,
#  ('E88', 'Z23'): 331,
#  ('E88', 'Z68'): 160,
#  ('E88', 'Z71'): 78,
#  ('E88', 'Z74'): 64,
#  ('E88', 'Z85'): 59,
#  ('E88', 'Z95'): 35,
#  ('H11', 'H25'): 415,
#  ('H11', 'H35'): 193,
#  ('H11', 'H52'): 218,
#  ('H11', 'H61'): 98,
#  ('H11', 'H90'): 79,
#  ('H11', 'I10'): 625,
#  ('H11', 'I11'): 65,
#  ('H11', 'I12'): 38,
#  ('H11', 'I13'): 14,
#  ('H11', 'I20'): 22,
#  ('H11', 'I21'): 21,
#  ('H11', 'I25'): 146,
#  ('H11', 'I42'): 28,
#  ('H11', 'I44'): 22,
#  ('H11', 'I48'): 64,
#  ('H11', 'I50'): 50,
#  ('H11', 'I51'): 68,
#  ('H11', 'I95'): 37,
#  ('H11', 'J18'): 49,
#  ('H11', 'J81'): 15,
#  ('H11', 'J90'): 29,
#  ('H11', 'J96'): 22,
#  ('H11', 'J98'): 72,
#  ('H11', 'K21'): 271,
#  ('H11', 'K57'): 123,
#  ('H11', 'L21'): 51,
#  ('H11', 'L30'): 101,
#  ('H11', 'L53'): 25,
#  ('H11', 'L57'): 206,
#  ('H11', 'L82'): 250,
#  ('H11', 'N17'): 36,
#  ('H11', 'N18'): 72,
#  ('H11', 'N28'): 76,
#  ('H11', 'N40'): 101,
#  ('H11', 'R00'): 159,
#  ('H11', 'R05'): 321,
#  ('H11', 'R06'): 281,
#  ('H11', 'R07'): 282,
#  ('H11', 'R09'): 148,
#  ('H11', 'R11'): 129,
#  ('H11', 'R13'): 68,
#  ('H11', 'R49'): 26,
#  ('H11', 'R60'): 117,
#  ('H61', 'I44'): 92,
#  ('H61', 'I48'): 275,
#  ('H61', 'I50'): 174,
#  ('H61', 'I51'): 193,
#  ('H61', 'I95'): 118,
#  ('H61', 'J18'): 229,
#  ('H61', 'J81'): 39,
#  ('H61', 'J90'): 111,
#  ('H61', 'J96'): 79,
#  ('H61', 'J98'): 241,
#  ('H61', 'K21'): 778,
#  ('H61', 'K57'): 312,
#  ('H61', 'L21'): 182,
#  ('H61', 'L30'): 330,
#  ('H61', 'L53'): 91,
#  ('H61', 'L57'): 624,
#  ('H61', 'L82'): 756,
#  ('H61', 'N17'): 105,
#  ('H61', 'N18'): 249,
#  ('H61', 'N28'): 212,
#  ('H61', 'N40'): 328,
#  ('H61', 'R00'): 450,
#  ('H61', 'R05'): 962,
#  ('H61', 'R06'): 760,
#  ('H61', 'R07'): 785,
#  ('H61', 'R09'): 478,
#  ('H61', 'R11'): 363,
#  ('H61', 'R13'): 193,
#  ('H61', 'R49'): 78,
#  ('H61', 'R60'): 311,
#  ('H61', 'R63'): 240,
#  ('H61', 'R68'): 245,
#  ('H61', 'R74'): 107,
#  ('H61', 'R79'): 204,
#  ('H61', 'R93'): 201,
#  ('H61', 'Z12'): 1286,
#  ('H61', 'Z23'): 2108,
#  ('H61', 'Z68'): 669,
#  ('H61', 'Z71'): 328,
#  ('H61', 'Z74'): 292,
#  ('H61', 'Z85'): 418,
#  ('H61', 'Z95'): 179,
#  ('H90', 'I10'): 1502,
#  ('H90', 'I11'): 158,
#  ('H90', 'I12'): 107,
#  ('H90', 'I13'): 36,
#  ('H90', 'I20'): 60,
#  ('H90', 'I21'): 44,
#  ('H90', 'I25'): 455,
#  ('H90', 'I42'): 60,
#  ('H90', 'I44'): 90,
#  ('H90', 'I48'): 263,
#  ('H90', 'I50'): 117,
#  ('H90', 'I51'): 159,
#  ('H90', 'I95'): 104,
#  ('H90', 'J18'): 186,
#  ('H90', 'J81'): 29,
#  ('H90', 'J90'): 93,
#  ('H90', 'J96'): 50,
#  ('H90', 'J98'): 211,
#  ('H90', 'K21'): 712,
#  ('H90', 'K57'): 346,
#  ('H90', 'L21'): 135,
#  ('H90', 'L30'): 257,
#  ('H90', 'L53'): 90,
#  ('H90', 'L57'): 684,
#  ('H90', 'L82'): 761,
#  ('H90', 'N17'): 82,
#  ('H90', 'N18'): 213,
#  ('H90', 'N28'): 196,
#  ('H90', 'N40'): 337,
#  ('H90', 'R00'): 404,
#  ('H90', 'R05'): 749,
#  ('H90', 'R06'): 686,
#  ('H90', 'R07'): 671,
#  ('H90', 'R09'): 392,
#  ('H90', 'R11'): 302,
#  ('H90', 'R13'): 191,
#  ('H90', 'R49'): 87,
#  ('H90', 'R60'): 286,
#  ('H90', 'R63'): 200,
#  ('H90', 'R68'): 216,
#  ('H90', 'R74'): 103,
#  ('H90', 'R79'): 190,
#  ('H90', 'R93'): 226,
#  ('H90', 'Z12'): 1128,
#  ('H90', 'Z23'): 1609,
#  ('H90', 'Z68'): 537,
#  ('H90', 'Z71'): 237,
#  ('H90', 'Z74'): 251,
#  ('H90', 'Z85'): 420,
#  ('H90', 'Z95'): 171,
#  ('I10', 'I11'): 1704,
#  ('I10', 'I12'): 1144,
#  ('I10', 'I13'): 388,
#  ('I10', 'I20'): 616,
#  ('I10', 'I21'): 493,
#  ('I10', 'I25'): 3859,
#  ('I10', 'I42'): 798,
#  ('I10', 'I44'): 633,
#  ('I10', 'I48'): 1937,
#  ('I10', 'I50'): 1471,
#  ('I10', 'I51'): 1720,
#  ('I10', 'I95'): 941,
#  ('I10', 'J18'): 1456,
#  ('I10', 'J81'): 401,
#  ...}

# %%
# Create a dataframe for the edges and weights and then write a csv
final_edges_df = pd.DataFrame({'Edge' : edges_dict.keys(),'Weight':edges_dict.values()})
final_edges_df['Source'] = final_edges_df['Edge'].str[0]
final_edges_df['Target'] = final_edges_df['Edge'].str[1]

# %%
# Load in the code-description pairs
code_description_pairs = pd.read_table('Data/code_description_pairs.txt', header=None)
code_description_pairs = code_description_pairs.rename({0:'Code', 1:'Description'}, axis=1)

# %%
# Join in the Source Descriptions
final_edges_df = pd.merge(final_edges_df, code_description_pairs, how = 'left', left_on = 'Source', right_on = 'Code')
final_edges_df = final_edges_df.rename({'Description': 'Source Description'}, axis=1)
final_edges_df = final_edges_df.drop('Code', axis = 1)

# %%
# Join in the Target Descriptions
final_edges_df = pd.merge(final_edges_df, code_description_pairs, how = 'left', left_on = 'Target', right_on = 'Code')
final_edges_df = final_edges_df.rename({'Description': 'Target Description'}, axis=1)
final_edges_df = final_edges_df.drop('Code', axis = 1)

# %%
# Sort the final_edges_df dataframe
final_edges_df = final_edges_df.sort_values(by = ['Weight', 'Source', 'Target'], ascending = [False, True, True]).reset_index(drop=True)
final_edges_df
# Out:
#               Edge  Weight Source Target  \
# 0       (Z00, Z23)   29990    Z00    Z23
# 1       (Z00, Z01)   17114    Z00    Z01
# 2       (E78, I10)   16020    E78    I10
# 3       (Z00, Z12)   14834    Z00    Z12
# 4       (Z01, Z23)   14621    Z01    Z23
# ...            ...     ...    ...    ...
# 544653  (Z81, Z96)       1    Z81    Z96
# 544654  (Z82, Z89)       1    Z82    Z89
# 544655  (Z84, Z93)       1    Z84    Z93
# 544656  (Z84, Z95)       1    Z84    Z95
# 544657  (Z84, Z97)       1    Z84    Z97
#
#                                        Source Description  \
# 0       General examination and investigation of perso...
# 1       General examination and investigation of perso...
# 2       Disorders of lipoprotein metabolism and other ...
# 3       General examination and investigation of perso...
# 4       Other special examinations and investigations ...
# ...                                                   ...
# 544653  Family history of mental and behavioural disor...
# 544654  Family history of certain disabilities and chr...
# 544655                 Family history of other conditions
# 544656                 Family history of other conditions
# 544657                 Family history of other conditions
#
#                                        Target Description
# 0       Need for immunization against single bacterial...
# 1       Other special examinations and investigations ...
# 2                        Essential (primary) hypertension
# 3             Special screening examination for neoplasms
# 4       Need for immunization against single bacterial...
# ...                                                   ...
# 544653              Presence of other functional implants
# 544654                           Acquired absence of limb
# 544655                          Artificial opening status
# 544656  Presence of cardiac and vascular implants and ...
# 544657                          Presence of other devices
#
# [544658 rows x 6 columns]

# %%
# Write the final_edges_df to csv
final_edges_df.to_csv('edges.csv')
